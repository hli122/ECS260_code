# %%
# Import libraries
import matplotlib.pyplot as plt # Matplotlib is used for plotting
import pandas as pd             # Pandas helps organize data structures
import numpy as np              # Numpy provides mathematical functions like sqrt()
import statsmodels.formula.api as smf  # Statsmodel provides linear regression

import statsmodels.api as sm
from scipy.stats import pearsonr

from mpl_toolkits.mplot3d import Axes3D

# %%
data=pd.read_csv('data_collection_1207.csv')
data
# Out:
#                                          project_name  stars_count  \
# 0   GitHub - maxi-booking/d8base-frontend: The PWA...            6
# 1   GitHub - KeyboardKit/KeyboardKit: KeyboardKit ...          627
# 2   GitHub - GetStream/stream-chat-swiftui: Offici...            6
# 3   GitHub - box/mojito: An automation platform th...          301
# 4   GitHub - Azure/azure-sdk-for-ios: iOS client S...          112
# 5   GitHub - KOKENY97/Cahue-BlastOff: Repositório ...            0
# 6   GitHub - microsoft/AdaptiveCards: A new way fo...         1100
# 7   GitHub - globules-io/OGX.JS: OGX.JS Javascript...            9
# 8   GitHub - UNIDY2002/THUInfo: An APP aimed at in...           57
# 9   GitHub - getsentry/sentry-cocoa: The official ...          458
# 10  GitHub - Oztechan/CCC: Currency Converter Calc...          146
# 11  GitHub - AnaBerigo/Cooking_Home-App-Recipes: A...            0
# 12  GitHub - SAP-samples/cloud-sdk-ios-specs: Depe...           10
# 13  GitHub - xsscx/srd: Welcome to Hoyt's SRD Repo...           18
# 14  GitHub - airbnb/swift: Airbnb's Swift Style Gu...         1400
# 15  GitHub - awslabs/aws-mobile-appsync-sdk-ios: i...          245
# 16  GitHub - madalin-dogaru/balaurul: Offensive to...            0
# 17  GitHub - BrainiumLLC/cargo-mobile: Rust on mob...          512
# 18  GitHub - metrodroid/metrodroid: Read data from...          272
# 19  GitHub - hiennguyen92/flutter_callkit_incoming...            5
# 20  GitHub - halildurmus/hotdeals-app: A community...            7
# 21  GitHub - justjavac/free-programming-books-zh_C...        84800
# 22  GitHub - Genymobile/scrcpy: Display and contro...        58400
# 23  GitHub - Hack-with-Github/Awesome-Hacking: A c...        47900
# 24  GitHub - horsicq/XAPKDetector: APK/DEX detecto...          328
# 25  GitHub - microsoft/surface-duo-sdk-samples-flu...           23
# 26  GitHub - Azure/azure-sdk-for-android: Android ...           57
# 27  GitHub - skaradimitriou/ElmepaUniApp: This app...            0
# 28  GitHub - wallabag/android-app: Android applica...          361
# 29  GitHub - RBusarow/ModuleCheck: Fast dependency...            5
# 30  GitHub - DeFiCh/wallet: DeFiChain Wallet. The ...           42
# 31  GitHub - ryanwong-uk/dazn-code-challenge: DAZN...            0
# 32  GitHub - arielm/chronotext-cross: Cross platfo...           18
# 33  GitHub - kylecorry31/Trail-Sense: An Android a...          270
# 34  GitHub - maxi-booking/d8base-frontend: The PWA...            6
# 35  GitHub - hiennguyen92/flutter_callkit_incoming...            5
# 36  GitHub - halildurmus/hotdeals-app: A community...            7
# 37  GitHub - AppiumTestDistribution/appium-device-...           50
# 38  GitHub - cloneconf/Nedium: Read Medium freely ...            0
# 39  GitHub - MaximeAeva/Poco: Tiny app to follow y...            0
# 40  GitHub - computefoundation/enterprise-android-...            9
# 41  GitHub - Steffanic/FriendSync: Let's Hang Out!...            0
# 42                               GitHub - SIKV/Photos           48
# 43  GitHub - kaaholst/android-squeezer: Remote con...           21
# 44                       GitHub - wszlosek/UJ-Android            0
# 45  GitHub - Oztechan/CCC: Currency Converter Calc...          146
# 46               GitHub - joaovitorcf97/GastoDeViagem            0
# 47  GitHub - Genymobile/scrcpy: Display and contro...        58400
# 48  GitHub - Hack-with-Github/Awesome-Hacking: A c...        47900
# 49          GitHub - manikantaraavi/manikantaraavi: 👀            0
#
#        Language   Domain  commits_count_total  commits_count_max  \
# 0    TypeScript      ios                 2030                824
# 1         Swift      ios                 1550                548
# 2         Swift      ios                   96                 35
# 3          Java      ios                 1026                157
# 4         Swift      ios                  838                258
# 5         Swift      ios                   81                 35
# 6           C++      ios                 3350               5681
# 7    JavaScript      ios                 1748                357
# 8    TypeScript      ios                 1348                771
# 9   Objective-C      ios                 1920                598
# 10       Kotlin      ios                 2010                564
# 11   JavaScript      ios                   10                  4
# 12         Ruby      ios                  225                 37
# 13     Assembly      ios                  992                149
# 14     Markdown      ios                  480                286
# 15        Swift      ios                  429                168
# 16          NaN      ios                   12                  9
# 17         Rust      ios                  456                193
# 18       Kotlin      ios                 4511                757
# 19       Kotlin      ios                   51                 17
# 20         Dart      ios                  403                 51
# 21          NaN  android                  911                595
# 22            C  android                 1474                219
# 23          NaN  android                  113                 84
# 24          C++  android                 3880               1236
# 25         Dart  android                   32                 67
# 26         Java  android                  780               2147
# 27       Kotlin  android                  223                168
# 28         Java  android                 2061                217
# 29       Kotlin  android                  355                101
# 30   TypeScript  android                  857                348
# 31       Kotlin  android                  163                 31
# 32          C++  android                  974                402
# 33       Kotlin  android                 2861                583
# 34   TypeScript  android                 2036                824
# 35       Kotlin  android                   51                 17
# 36         Dart  android                  403                 51
# 37   TypeScript  android                  305                148
# 38       Kotlin  android                   84                 22
# 39       Kotlin  android                    8                  7
# 40         Java  android                   11                 11
# 41         Dart  android                   30                 16
# 42       Kotlin  android                  271                332
# 43         Java  android                 2236                458
# 44       Kotlin  android                   50                191
# 45       Kotlin  android                 2010                564
# 46       Kotlin  android                    1                  1
# 47            C  android                 1474                219
# 48          NaN  android                  113                 84
# 49          NaN  android                 4307               4263
#
#     commits_count_avg  contributors_count_max  minor_count_max  \
# 0                   7                       5                5
# 1                   7                       3                3
# 2                   1                       1                1
# 3                   2                       6               10
# 4                   6                       6                7
# 5                   2                       1                0
# 6                   4                       7               29
# 7                  12                       2                1
# 8                   8                       3                2
# 9                   6                       6               18
# 10                 12                       2                1
# 11                  1                       2                0
# 12                  2                       3                3
# 13                  2                       1                0
# 14                 31                       5               26
# 15                  4                       6               14
# 16                  4                       1                0
# 17                  7                       3                4
# 18                  6                       5               10
# 19                  2                       1                0
# 20                  5                       3                2
# 21                 56                       4              124
# 22                 15                       4               41
# 23                 19                       3               20
# 24                 41                       1                1
# 25                  2                       3                0
# 26                  3                       6                9
# 27                  4                       1                0
# 28                  7                       7               24
# 29                  5                       4                2
# 30                  8                       6                5
# 31                  3                       1                1
# 32                  4                       1                0
# 33                  7                       6                7
# 34                  7                       5                5
# 35                  2                       1                0
# 36                  5                       3                2
# 37                  4                       6                6
# 38                  2                       1                0
# 39                  1                       1                0
# 40                  1                       1                0
# 41                  1                       1                0
# 42                  3                       2                1
# 43                  5                       5                7
# 44                  2                       1                0
# 45                 12                       2                1
# 46                  1                       1                0
# 47                 15                       4               41
# 48                 19                       3               20
# 49                391                       2                0
#
#     contributors_count_avg  minor_count_avg  created year
# 0                        1                0          2019
# 1                        1                0          2016
# 2                        1                0          2021
# 3                        1                0          2016
# 4                        1                0          2018
# 5                        1                0          2021
# 6                        1                0          2016
# 7                        1                0          2016
# 8                        1                0          2020
# 9                        1                0          2016
# 10                       1                0          2017
# 11                       1                0          2021
# 12                       1                0          2019
# 13                       1                0          2021
# 14                       2                4          2016
# 15                       1                0          2017
# 16                       1                0          2021
# 17                       1                0          2020
# 18                       1                0          2015
# 19                       1                0          2021
# 20                       1                0          2021
# 21                       1               12          2013
# 22                       1                1          2017
# 23                       2                7          2016
# 24                       1                0          2020
# 25                       1                0          2020
# 26                       1                0          2018
# 27                       1                0          2020
# 28                       1                0          2014
# 29                       1                0          2020
# 30                       2                0          2021
# 31                       1                0          2021
# 32                       1                0          2015
# 33                       1                0          2019
# 34                       1                0          2019
# 35                       1                0          2021
# 36                       1                0          2021
# 37                       1                0          2021
# 38                       1                0          2021
# 39                       1                0          2021
# 40                       1                0          2018
# 41                       1                0          2021
# 42                       1                0          2018
# 43                       1                0          2011
# 44                       1                0          2021
# 45                       1                0          2017
# 46                       1                0          2021
# 47                       1                1          2017
# 48                       2                7          2016
# 49                       1                0          2021

# %%
data2 = data[['stars_count', 'Language', 'Domain', 'created year', 'commits_count_total', 'contributors_count_max', 'minor_count_max']]
data2
# Out:
#     stars_count     Language   Domain  created year  commits_count_total  \
# 0             6   TypeScript      ios          2019                 2030
# 1           627        Swift      ios          2016                 1550
# 2             6        Swift      ios          2021                   96
# 3           301         Java      ios          2016                 1026
# 4           112        Swift      ios          2018                  838
# 5             0        Swift      ios          2021                   81
# 6          1100          C++      ios          2016                 3350
# 7             9   JavaScript      ios          2016                 1748
# 8            57   TypeScript      ios          2020                 1348
# 9           458  Objective-C      ios          2016                 1920
# 10          146       Kotlin      ios          2017                 2010
# 11            0   JavaScript      ios          2021                   10
# 12           10         Ruby      ios          2019                  225
# 13           18     Assembly      ios          2021                  992
# 14         1400     Markdown      ios          2016                  480
# 15          245        Swift      ios          2017                  429
# 16            0          NaN      ios          2021                   12
# 17          512         Rust      ios          2020                  456
# 18          272       Kotlin      ios          2015                 4511
# 19            5       Kotlin      ios          2021                   51
# 20            7         Dart      ios          2021                  403
# 21        84800          NaN  android          2013                  911
# 22        58400            C  android          2017                 1474
# 23        47900          NaN  android          2016                  113
# 24          328          C++  android          2020                 3880
# 25           23         Dart  android          2020                   32
# 26           57         Java  android          2018                  780
# 27            0       Kotlin  android          2020                  223
# 28          361         Java  android          2014                 2061
# 29            5       Kotlin  android          2020                  355
# 30           42   TypeScript  android          2021                  857
# 31            0       Kotlin  android          2021                  163
# 32           18          C++  android          2015                  974
# 33          270       Kotlin  android          2019                 2861
# 34            6   TypeScript  android          2019                 2036
# 35            5       Kotlin  android          2021                   51
# 36            7         Dart  android          2021                  403
# 37           50   TypeScript  android          2021                  305
# 38            0       Kotlin  android          2021                   84
# 39            0       Kotlin  android          2021                    8
# 40            9         Java  android          2018                   11
# 41            0         Dart  android          2021                   30
# 42           48       Kotlin  android          2018                  271
# 43           21         Java  android          2011                 2236
# 44            0       Kotlin  android          2021                   50
# 45          146       Kotlin  android          2017                 2010
# 46            0       Kotlin  android          2021                    1
# 47        58400            C  android          2017                 1474
# 48        47900          NaN  android          2016                  113
# 49            0          NaN  android          2021                 4307
#
#     contributors_count_max  minor_count_max
# 0                        5                5
# 1                        3                3
# 2                        1                1
# 3                        6               10
# 4                        6                7
# 5                        1                0
# 6                        7               29
# 7                        2                1
# 8                        3                2
# 9                        6               18
# 10                       2                1
# 11                       2                0
# 12                       3                3
# 13                       1                0
# 14                       5               26
# 15                       6               14
# 16                       1                0
# 17                       3                4
# 18                       5               10
# 19                       1                0
# 20                       3                2
# 21                       4              124
# 22                       4               41
# 23                       3               20
# 24                       1                1
# 25                       3                0
# 26                       6                9
# 27                       1                0
# 28                       7               24
# 29                       4                2
# 30                       6                5
# 31                       1                1
# 32                       1                0
# 33                       6                7
# 34                       5                5
# 35                       1                0
# 36                       3                2
# 37                       6                6
# 38                       1                0
# 39                       1                0
# 40                       1                0
# 41                       1                0
# 42                       2                1
# 43                       5                7
# 44                       1                0
# 45                       2                1
# 46                       1                0
# 47                       4               41
# 48                       3               20
# 49                       2                0

# %%
reg_commit = smf.ols('stars_count ~ 1 + commits_count_total', data=data2).fit()
reg_commit.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            stars_count   R-squared:                       0.002
# Model:                            OLS   Adj. R-squared:                 -0.019
# Method:                 Least Squares   F-statistic:                   0.07401
# Date:                Tue, 07 Dec 2021   Prob (F-statistic):              0.787
# Time:                        22:09:42   Log-Likelihood:                -561.66
# No. Observations:                  50   AIC:                             1127.
# Df Residuals:                      48   BIC:                             1131.
# Df Model:                           1
# Covariance Type:            nonrobust
# =======================================================================================
#                           coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# Intercept            6716.8509   3524.399      1.906      0.063    -369.428    1.38e+04
# commits_count_total    -0.6149      2.260     -0.272      0.787      -5.160       3.930
# ==============================================================================
# Omnibus:                       51.761   Durbin-Watson:                   0.948
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              194.009
# Skew:                           2.966   Prob(JB):                     7.44e-43
# Kurtosis:                      10.611   Cond. No.                     2.08e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.08e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
beta0, beta1 = reg_commit.params.Intercept, reg_commit.params.commits_count_total
x = data2['commits_count_total'].sort_values()
y = beta0 + beta1*x 

fig, ax = plt.subplots()
ax.scatter(data2['commits_count_total'], data2['stars_count'])
ax.set_xlabel('commits_count')
ax.set_ylabel('stars_count')

ax.plot(x, y)

plt.show()

# %%
data_new = sm.add_constant(data2[['commits_count_total']])
y_hat = reg_commit.predict(data_new)
corr, p = pearsonr(data2['stars_count'], y_hat)
print(corr)
# Out:
# 0.03923571284333963

# %%
reg_ctrb = smf.ols('stars_count ~ 1 + contributors_count_max + minor_count_max', data=data2).fit()
reg_ctrb.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            stars_count   R-squared:                       0.724
# Model:                            OLS   Adj. R-squared:                  0.712
# Method:                 Least Squares   F-statistic:                     61.64
# Date:                Tue, 07 Dec 2021   Prob (F-statistic):           7.28e-14
# Time:                        22:59:56   Log-Likelihood:                -529.52
# No. Observations:                  50   AIC:                             1065.
# Df Residuals:                      47   BIC:                             1071.
# Df Model:                           2
# Covariance Type:            nonrobust
# ==========================================================================================
#                              coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------
# Intercept               4899.2216   2642.202      1.854      0.070    -416.203    1.02e+04
# contributors_count_max -2081.1372    755.227     -2.756      0.008   -3600.457    -561.817
# minor_count_max          856.3921     77.579     11.039      0.000     700.323    1012.461
# ==============================================================================
# Omnibus:                       34.881   Durbin-Watson:                   1.443
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               83.410
# Skew:                           2.026   Prob(JB):                     7.72e-19
# Kurtosis:                       7.859   Cond. No.                         41.5
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
data_new2 = sm.add_constant(data2[['contributors_count_max', 'minor_count_max']])
y_hat2 = reg_ctrb.predict(data_new2)

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.scatter(data2['contributors_count_max'], data2['minor_count_max'], data2['stars_count'])
#ax.plot(data3['minor_contributors'], data3['normal_contributors'], y_hat2)
ax.plot_trisurf(data2['contributors_count_max'], data2['minor_count_max'], y_hat2)
ax.set_xlabel('normal_contributors')
ax.set_ylabel('minor_contributors')
ax.set_zlabel('stars_count')
plt.show()

# %%
corr, p = pearsonr(data2['stars_count'], y_hat2)
print(corr)
# Out:
# 0.8508686710887623

# %%
data2['stars_count'] = pd.to_numeric(data2['stars_count'])
# Out:
# <ipython-input-15-69c8af578f1f>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data2['stars_count'] = pd.to_numeric(data2['stars_count'])

# %%
data_p = data2[data2['stars_count'] > 100]
data_p
# Out:
#     stars_count     Language   Domain  created year  commits_count_total  \
# 1           627        Swift      ios          2016                 1550
# 3           301         Java      ios          2016                 1026
# 4           112        Swift      ios          2018                  838
# 6          1100          C++      ios          2016                 3350
# 9           458  Objective-C      ios          2016                 1920
# 10          146       Kotlin      ios          2017                 2010
# 14         1400     Markdown      ios          2016                  480
# 15          245        Swift      ios          2017                  429
# 17          512         Rust      ios          2020                  456
# 18          272       Kotlin      ios          2015                 4511
# 21        84800          NaN  android          2013                  911
# 22        58400            C  android          2017                 1474
# 23        47900          NaN  android          2016                  113
# 24          328          C++  android          2020                 3880
# 28          361         Java  android          2014                 2061
# 33          270       Kotlin  android          2019                 2861
# 45          146       Kotlin  android          2017                 2010
# 47        58400            C  android          2017                 1474
# 48        47900          NaN  android          2016                  113
#
#     contributors_count_max  minor_count_max
# 1                        3                3
# 3                        6               10
# 4                        6                7
# 6                        7               29
# 9                        6               18
# 10                       2                1
# 14                       5               26
# 15                       6               14
# 17                       3                4
# 18                       5               10
# 21                       4              124
# 22                       4               41
# 23                       3               20
# 24                       1                1
# 28                       7               24
# 33                       6                7
# 45                       2                1
# 47                       4               41
# 48                       3               20

# %%
print(len(data_p))
# Out:
# 19

# %%
data_np = data2[data2['stars_count'] <= 100]
data_np
# Out:
#     stars_count    Language   Domain  created year  commits_count_total  \
# 0             6  TypeScript      ios          2019                 2030
# 2             6       Swift      ios          2021                   96
# 5             0       Swift      ios          2021                   81
# 7             9  JavaScript      ios          2016                 1748
# 8            57  TypeScript      ios          2020                 1348
# 11            0  JavaScript      ios          2021                   10
# 12           10        Ruby      ios          2019                  225
# 13           18    Assembly      ios          2021                  992
# 16            0         NaN      ios          2021                   12
# 19            5      Kotlin      ios          2021                   51
# 20            7        Dart      ios          2021                  403
# 25           23        Dart  android          2020                   32
# 26           57        Java  android          2018                  780
# 27            0      Kotlin  android          2020                  223
# 29            5      Kotlin  android          2020                  355
# 30           42  TypeScript  android          2021                  857
# 31            0      Kotlin  android          2021                  163
# 32           18         C++  android          2015                  974
# 34            6  TypeScript  android          2019                 2036
# 35            5      Kotlin  android          2021                   51
# 36            7        Dart  android          2021                  403
# 37           50  TypeScript  android          2021                  305
# 38            0      Kotlin  android          2021                   84
# 39            0      Kotlin  android          2021                    8
# 40            9        Java  android          2018                   11
# 41            0        Dart  android          2021                   30
# 42           48      Kotlin  android          2018                  271
# 43           21        Java  android          2011                 2236
# 44            0      Kotlin  android          2021                   50
# 46            0      Kotlin  android          2021                    1
# 49            0         NaN  android          2021                 4307
#
#     contributors_count_max  minor_count_max
# 0                        5                5
# 2                        1                1
# 5                        1                0
# 7                        2                1
# 8                        3                2
# 11                       2                0
# 12                       3                3
# 13                       1                0
# 16                       1                0
# 19                       1                0
# 20                       3                2
# 25                       3                0
# 26                       6                9
# 27                       1                0
# 29                       4                2
# 30                       6                5
# 31                       1                1
# 32                       1                0
# 34                       5                5
# 35                       1                0
# 36                       3                2
# 37                       6                6
# 38                       1                0
# 39                       1                0
# 40                       1                0
# 41                       1                0
# 42                       2                1
# 43                       5                7
# 44                       1                0
# 46                       1                0
# 49                       2                0

# %%
print(len(data_np))
# Out:
# 31

# %%
dom_count_p = data_p.groupby('Domain').size()
dom_count_p
# Out:
# Domain
# android     9
# ios        10
# dtype: int64

# %%
dom_count_p.plot.bar()
plt.title('Popular')
# Out:
# Text(0.5, 1.0, 'Popular')

# %%
dom_count_np = data_np.groupby('Domain').size()
dom_count_np
# Out:
# Domain
# android    20
# ios        11
# dtype: int64

# %%
dom_count_np.plot.bar()
plt.title('Non-Popular')
# Out:
# Text(0.5, 1.0, 'Non-Popular')

# %%
data_1314 = data_p[data_p['created year'].isin(['2013', '2014'])]
data_1314
# Out:
#     stars_count Language   Domain  created year  commits_count_total  \
# 21        84800      NaN  android          2013                  911
# 28          361     Java  android          2014                 2061
#
#     contributors_count_max  minor_count_max
# 21                       4              124
# 28                       7               24
